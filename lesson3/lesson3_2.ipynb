# %%
print("Hello! Python")
# Out:
# Hello! Python

# %%
a = 10
b = 3
print(a + b)   # 13
print(a / b)   # 3.333...（浮點數除法）
print(a // b)  # 3     （整數除法，取商）
print(a % b)   # 1     （取餘數）
print(a ** b)  # 1000  （次方）
# Out:
# 13
# 3.3333333333333335
# 3
# 1
# 1000

# %%
n1 = 5 + 10
n2 = 20 - 15
n1
n2
# Out:
# 5

# %%
print(10)
print(20 + 10)
# Out:
# 10
# 30

# %%
a
b
# Out:
# 3

# %%
m1 = 5
m2 = 5.0
m3 = '5.0'
m4 = "5.0"
m5 = True
print(type(m1))
print(type(m2))
print(type(m3))
print(type(m4))
print(type(m5))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'bool'>

# %%
print(5 + 5)
print(5 + 5.0)
# print(5 + '5') 這是錯的,數值+字串(會出錯)
print('5' + '5')
print('=' * 20)
# Out:
# 10
# 10.0
# 55
# ...

# %%
apple = 7
orange = 10

print('apple有5個,orange有10個')
print("apple有" + str(apple) + "個,orange有" + str(orange) + "個")  #str()變數轉字串
print(f"apple有{apple}個,orange有{orange}個") #字串插補 #f格式化 #{變數}
# Out:
# apple有5個,orange有10個
# apple有7個,orange有10個
# apple有7個,orange有10個

# %%
chinese = 55
chinese = chinese + 7
chinese
# Out:
# 62

# %%
chinese = 55
chinese += 5    #複合指定運算子
chinese
# Out:
# 60

# %%
english = 10
english += 15
english *= 4
english
# Out:
# 100
