# %%
age = int(input('請輸入age:'))
if age >= 18:
    print("可以考駕照！")
    print('='*20)
else:
    print("不可以考駕照！")
    print('='*20)

print("應用程式結束！")
# Out:
# 不可以考駕照！
# ...
# 應用程式結束！

# %% [markdown]
# Python 小考：BMI 計算練習
# 請撰寫一個程式，依序完成下列需求：
#
# 透過 input() 取得使用者的身高（公分）與體重（公斤）。
#
# 先將身高換算為公尺，套用公式 BMI = 體重(公斤) / (身高(公尺) ** 2) 計算 BMI。
#
# 輸出格式示例：
#
# BMI：23.24

# %%
height_cm = float(input("請輸入身高(公分)："))
weight_kg = float(input("請輸入體重(公斤)："))

height_m = height_cm / 100
bmi = weight_kg / (height_m ** 2)

print(f"BMI：{bmi:.2f}")
# Out:
# BMI：20.70
